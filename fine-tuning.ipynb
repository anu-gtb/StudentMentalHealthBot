# %%
import torch
from transformers import GPT2LMHeadModel,GPT2Tokenizer,TrainingArguments,Trainer,TextDataset,DataCollatorForLanguageModeling

# %%
model_name='gpt2'
tokenizer=GPT2Tokenizer.from_pretrained(model_name)
model=GPT2LMHeadModel.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def load_dataset(file_path,tokenizer,block_size=1024):
    train_data=TextDataset(tokenizer=tokenizer,file_path=file_path,block_size=block_size)
    return train_data

# %%
def load_data_collator(tokenizer,mlm=False):
    data_collator=DataCollatorForLanguageModeling(tokenizer=tokenizer,mlm=mlm)
    return data_collator

# %%
def train(train_file_path,model_name,output_dir,overwrite_output_dir,train_batch_size,epochs):
    tokenizer=GPT2Tokenizer.from_pretrained(model_name)
    train_data=load_dataset(train_file_path,tokenizer)

    data_collator=load_data_collator(tokenizer)

    tokenizer.save_pretrained(output_dir)

    model=GPT2LMHeadModel.from_pretrained(model_name)
    model.save_pretrained(output_dir)

    training_arguments=TrainingArguments(
        output_dir=output_dir,
        overwrite_output_dir=overwrite_output_dir,
        num_train_epochs=epochs,
        per_device_train_batch_size=train_batch_size,
        logging_dir='./log',
        logging_steps=100,
        save_steps=150,
        logging_first_step=True,
        save_total_limit=2,
        learning_rate=0.001,
      )

    trainer=Trainer(
        model=model,
        args=training_arguments,
        data_collator=data_collator,
        train_dataset=train_data
    )
    hist=trainer.train()
    trainer.save_model()
    return trainer,hist

# %%
train_file_path='C:\\Users\\DELL\\Documents\\HACK_CONCLAVE\\final_bot.csv'
model_name=model_name
output_dir='./model'
overwrite_output_dir=True
train_batch_size=3
epochs=17

# %%
hist=train(
    train_file_path=train_file_path,
    model_name=model_name,
    output_dir=output_dir,
    overwrite_output_dir=overwrite_output_dir,
    train_batch_size=train_batch_size,
    epochs=epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/data/datasets/language_modeling.py:54: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/language-modeling/run_mlm.py
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1033
#   Num Epochs = 17
#   Instantaneous batch size per device = 3
#   Total train batch size (w. parallel, distributed & accumulation) = 3
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5865
#     <div>
#
#       <progress value='5865' max='5865' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5865/5865 1:55:34, Epoch 17/17]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.892200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>3.457600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>3.043500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.943000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.357800</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>2.228200</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>2.253400</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>2.126400</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.625600</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.678800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.649400</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.337400</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.210000</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.214400</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.160400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.885000</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.915200</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.859800</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.692100</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.626000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.674700</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.595200</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.440400</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.521700</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.470100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.367200</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.334200</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.382800</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.294200</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.235100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.274400</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.294200</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.216600</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.185600</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.201400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.173400</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.163400</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.159100</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.153600</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.115600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.115400</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.112300</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.095800</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.093400</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.081100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.079400</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.072700</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.059200</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.055500</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.051900</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.043700</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.043300</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.047900</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.033900</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.036800</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.033100</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.031800</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.026600</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.028800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./model/checkpoint-150
# Configuration saved in ./model/checkpoint-150/config.json
# Model weights saved in ./model/checkpoint-150/pytorch_model.bin
# Saving model checkpoint to ./model/checkpoint-300
# Configuration saved in ./model/checkpoint-300/config.json
# Model weights saved in ./model/checkpoint-300/pytorch_model.bin
# Saving model checkpoint to ./model/checkpoint-450
# Configuration saved in ./model/checkpoint-450/config.json
# Model weights saved in ./model/checkpoint-450/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-150] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-600
# Configuration saved in ./model/checkpoint-600/config.json
# Model weights saved in ./model/checkpoint-600/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-300] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-750
# Configuration saved in ./model/checkpoint-750/config.json
# Model weights saved in ./model/checkpoint-750/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-450] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-900
# Configuration saved in ./model/checkpoint-900/config.json
# Model weights saved in ./model/checkpoint-900/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-600] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-1050
# Configuration saved in ./model/checkpoint-1050/config.json
# Model weights saved in ./model/checkpoint-1050/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-750] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-1200
# Configuration saved in ./model/checkpoint-1200/config.json
# Model weights saved in ./model/checkpoint-1200/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-900] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-1350
# Configuration saved in ./model/checkpoint-1350/config.json
# Model weights saved in ./model/checkpoint-1350/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-1050] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-1500
# Configuration saved in ./model/checkpoint-1500/config.json
# Model weights saved in ./model/checkpoint-1500/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-1200] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-1650
# Configuration saved in ./model/checkpoint-1650/config.json
# Model weights saved in ./model/checkpoint-1650/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-1350] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-1800
# Configuration saved in ./model/checkpoint-1800/config.json
# Model weights saved in ./model/checkpoint-1800/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-1950
# Configuration saved in ./model/checkpoint-1950/config.json
# Model weights saved in ./model/checkpoint-1950/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-1650] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-2100
# Configuration saved in ./model/checkpoint-2100/config.json
# Model weights saved in ./model/checkpoint-2100/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-1800] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-2250
# Configuration saved in ./model/checkpoint-2250/config.json
# Model weights saved in ./model/checkpoint-2250/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-1950] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-2400
# Configuration saved in ./model/checkpoint-2400/config.json
# Model weights saved in ./model/checkpoint-2400/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-2100] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-2550
# Configuration saved in ./model/checkpoint-2550/config.json
# Model weights saved in ./model/checkpoint-2550/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-2250] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-2700
# Configuration saved in ./model/checkpoint-2700/config.json
# Model weights saved in ./model/checkpoint-2700/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-2400] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-2850
# Configuration saved in ./model/checkpoint-2850/config.json
# Model weights saved in ./model/checkpoint-2850/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-2550] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-3000
# Configuration saved in ./model/checkpoint-3000/config.json
# Model weights saved in ./model/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-2700] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-3150
# Configuration saved in ./model/checkpoint-3150/config.json
# Model weights saved in ./model/checkpoint-3150/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-2850] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-3300
# Configuration saved in ./model/checkpoint-3300/config.json
# Model weights saved in ./model/checkpoint-3300/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-3450
# Configuration saved in ./model/checkpoint-3450/config.json
# Model weights saved in ./model/checkpoint-3450/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-3150] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-3600
# Configuration saved in ./model/checkpoint-3600/config.json
# Model weights saved in ./model/checkpoint-3600/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-3300] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-3750
# Configuration saved in ./model/checkpoint-3750/config.json
# Model weights saved in ./model/checkpoint-3750/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-3450] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-3900
# Configuration saved in ./model/checkpoint-3900/config.json
# Model weights saved in ./model/checkpoint-3900/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-3600] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-4050
# Configuration saved in ./model/checkpoint-4050/config.json
# Model weights saved in ./model/checkpoint-4050/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-3750] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-4200
# Configuration saved in ./model/checkpoint-4200/config.json
# Model weights saved in ./model/checkpoint-4200/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-3900] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-4350
# Configuration saved in ./model/checkpoint-4350/config.json
# Model weights saved in ./model/checkpoint-4350/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-4050] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-4500
# Configuration saved in ./model/checkpoint-4500/config.json
# Model weights saved in ./model/checkpoint-4500/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-4200] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-4650
# Configuration saved in ./model/checkpoint-4650/config.json
# Model weights saved in ./model/checkpoint-4650/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-4350] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-4800
# Configuration saved in ./model/checkpoint-4800/config.json
# Model weights saved in ./model/checkpoint-4800/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-4950
# Configuration saved in ./model/checkpoint-4950/config.json
# Model weights saved in ./model/checkpoint-4950/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-4650] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-5100
# Configuration saved in ./model/checkpoint-5100/config.json
# Model weights saved in ./model/checkpoint-5100/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-4800] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-5250
# Configuration saved in ./model/checkpoint-5250/config.json
# Model weights saved in ./model/checkpoint-5250/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-4950] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-5400
# Configuration saved in ./model/checkpoint-5400/config.json
# Model weights saved in ./model/checkpoint-5400/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-5100] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-5550
# Configuration saved in ./model/checkpoint-5550/config.json
# Model weights saved in ./model/checkpoint-5550/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-5250] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-5700
# Configuration saved in ./model/checkpoint-5700/config.json
# Model weights saved in ./model/checkpoint-5700/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-5400] due to args.save_total_limit
# Saving model checkpoint to ./model/checkpoint-5850
# Configuration saved in ./model/checkpoint-5850/config.json
# Model weights saved in ./model/checkpoint-5850/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-5550] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Saving model checkpoint to ./model
# Configuration saved in ./model/config.json
# Model weights saved in ./model/pytorch_model.bin
